# %%
# %pip install mesaPlot
# Out:
# ...
#      ---------------------------------------- 0.0/51.6 kB ? eta -:--:--
#      ---------------------------------------- 51.6/51.6 kB 1.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/317.1 kB ? eta -:--:--
#      ---------------------- --------------- 184.3/317.1 kB 5.6 MB/s eta 0:00:01
#      -------------------------------------- 317.1/317.1 kB 4.9 MB/s eta 0:00:00
# ...
#   Using cached tomli-2.0.1-py3-none-any.whl (12 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\mk102\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\mk102\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\mk102\appdata\local\programs\python\python310\lib\site-packages)
# ...

# %%
# %pip install astro-tulips
# Out:
# ...
#      ---------------------------------------- 0.0/59.9 kB ? eta -:--:--
#      ---------------------------------------- 59.9/59.9 kB 1.6 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/78.5 kB ? eta -:--:--
#      ---------------------------------------- 78.5/78.5 kB 4.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/367.1 kB ? eta -:--:--
#      -------------- ----------------------- 143.4/367.1 kB 4.3 MB/s eta 0:00:01
#      ---------------------------- --------- 276.5/367.1 kB 3.4 MB/s eta 0:00:01
#      -------------------------------------- 367.1/367.1 kB 3.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/22.6 MB ? eta -:--:--
#      ---------------------------------------- 0.1/22.6 MB 3.3 MB/s eta 0:00:07
#      ---------------------------------------- 0.2/22.6 MB 2.8 MB/s eta 0:00:09
#       --------------------------------------- 0.4/22.6 MB 3.0 MB/s eta 0:00:08
# ...
